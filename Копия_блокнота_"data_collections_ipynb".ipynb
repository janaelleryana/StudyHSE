# %% [markdown]
# <a href="https://colab.research.google.com/github/janaelleryana/StudyHSE/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22data_collections_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Синтаксис

# %% [markdown]
# **Задача 1**
#
# Создайте список mixed_data, содержащий:
#
# - 3 числа (int)
# - 2 строки (str)
# - 1 вложенный список
# - 1 кортеж
# - 1 множество
#
# Добавьте в конец списка число 123
#
# Удалите вторую строку из списка
#
# Вставьте строку "inserted" на позицию 2
#
# Выведите итоговый список

# %%
### ваш код здесь ###

# %% [markdown]
# **Задача 2**
#
# Создайте кортеж user_credentials, содержащий:
#
# - Логин (строка)
#
# - Хэш пароля (строка)
#
# - Уровень доступа (целое число)
#
# Попробуйте изменить уровень доступа (должна возникнуть ошибка)
#
# Напишите комментарий, почему кортеж подходит для хранения таких данных

# %%
### ваш код здесь ###

# %% [markdown]
# **Задача 3**
#
# Дано:

# %%
tags1 = {"python", "ml", "data"}
tags2 = {"ml", "nlp", "deeplearning"}

# %% [markdown]
# Найдите:
#
# - Общие теги (пересечение)
#
# - Все уникальные теги (объединение)
#
# - Теги, которые есть в tags1, но нет в tags2

# %%
### ваш код здесь ###

# %% [markdown]
# ### Фильтрация и обработка текстовых данных

# %% [markdown]
# 1. Установите nltk и загрузите стоп-слова для русского и английского языков
#
# *Уже выполнено: просто запустите эту ячейку*

# %%
import nltk
import string
from nltk.corpus import stopwords

# Установка nltk и загрузка стоп-слов
nltk.download('stopwords')

# Загрузка стоп-слов для русского и английского языков
stopwords_english = stopwords.words('english')
stopwords_russian = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# 2. Конвертируйте списки слов на русском и английском, приведите их к виду множства `set`
#
# *Это стандартная операция: работа со стоп-словами всегда начинается с фильтрации, удаления дубликатов*

# %%
russian_set = set(stopwords_russian)
english_set = set(stopwords_english)

# %% [markdown]
# 3. Выведите на экран первые 10 стоп-слов из двух списков
#
# *Подумайте, как это сделать, ведь `set` нельзя индексировать, а созданный список слов нельзя перезаписывать*

# %%
for index, word in zip(range(10), russian_set):
  print(word)
print('_______________')
for index, word in zip(range(10), english_set):
  print(word)
# Out:
# этом
# из
# есть
# ему
# если
# уж
# опять
# какая
# конечно
# впрочем
# _______________
# same
# where
# yours
# during
# won
# wouldn
# when
# wasn
# do
# why

# %% [markdown]
# 4. Дан текст

# %%
# Исходный текст
text = """
This is a sample text for processing. It contains some stopwords and important words.
Этот текст содержит как английские, так и русские слова, включая стоп-слова.
"""

# %% [markdown]
# Допишите функцию в указанном плейсхолдере
#
# Функция:
#
# - удаляет знаки препинания
# - разбивает текст на слова
# - приводит текст к нижнему регистру

# %%
import re
# Токенизация текста на слова
def tokenize_text(text):
    # Убираем знаки препинания и разбиваем на слова
    cleaned_text = re.sub(r'[^\w\s]', '', text)
    words = cleaned_text.split()

    return words

# %% [markdown]
# Применим нашу функцию к тексту

# %%
text = """
This is a sample text for processing. It contains some stopwords and important words.
Этот текст содержит как английские, так и русские слова, включая стоп-слова.
"""
words = tokenize_text(text.lower())
print(words)
# Out:
# ['this', 'is', 'a', 'sample', 'text', 'for', 'processing', 'it', 'contains', 'some', 'stopwords', 'and', 'important', 'words', 'этот', 'текст', 'содержит', 'как', 'английские', 'так', 'и', 'русские', 'слова', 'включая', 'стопслова']

# %% [markdown]
# Выведите на экран список токенов и общее количество слов

# %%
print(words)
print(len(words))
# Out:
# ['this', 'is', 'a', 'sample', 'text', 'for', 'processing', 'it', 'contains', 'some', 'stopwords', 'and', 'important', 'words', 'этот', 'текст', 'содержит', 'как', 'английские', 'так', 'и', 'русские', 'слова', 'включая', 'стопслова']
# 25

# %% [markdown]
# 5. Произведите фильтрацию стоп-слов для двух языков
#
# - Создайте пустой список
# - Запустите цикл for (`for word in words`, для каждого слова в списке слов)
# - Если слова нет в списке стоп-слов
# - Сделайте `append` в созданный список
#
# *Допишите функцию*

# %%
# Фильтрация стоп-слов для обоих языков
def filter_stopwords(words, stopwords_set):
    new_list = []
    for word in words:
     if word not in stopwords_set:
      new_list.append(word)
    return new_list

# %% [markdown]
# 6. Примените операции со множествами

# %%
# Объедините стоп-слова обоих языков в общее множество
all_stopwords = russian_set.union(english_set)

print(all_stopwords)
# Out:
# {'same', 'where', 'yours', 'этом', 'из', 'есть', 'won', 'wouldn', 'when', 'wasn', 'опять', 'do', 'why', 'конечно', 'an', 'on', 'сейчас', 'много', 'couldn', "i'd", 'с', 'этот', 'and', 'нибудь', 'am', 'most', 'once', 'что', "they'd", 'она', 'нет', 'все', 'does', "wouldn't", 'theirs', 'они', 'shouldn', 'having', 'всех', 'had', 'эту', "couldn't", 'мне', 'то', 'off', 'but', 'for', 've', "you're", 'ты', 'них', 'hers', 'have', 'сам', 'so', 'at', "we'd", 'is', 'then', 'very', 'not', 'к', 'вы', "it'd", "she'd", 'тебя', 'ни', 'почти', 'эти', 'how', 'тоже', 'about', 'between', "you'll", 'because', 'himself', 'об', 'мой', 'this', 'бы', 'всю', 'как', 'чтоб', "haven't", 'будет', 'ourselves', 'себе', 'там', 'другой', "he'd", 'the', 'на', 'по', 'didn', 'which', 'if', 'за', 'раз', 'он', 'your', "weren't", 'ним', "she'll", 'doing', 'against', "don't", 'under', 'did', 'mightn', 'all', 'ma', "we'll", 'у', 'yourself', 'будто', 't', 'над', 'всегда', 'up', 'his', 'вот', 'всего', 'shan', 'him', 'я', 'we', 'но', 'from', 'he', "should've", 'со', 'nor', 'им', "mightn't", 'его', 's', 'hadn', 'при', "it's", 'были', 'о', 'haven', 'чего', 'weren', 'свою', 're', 'mustn', 'нельзя', 'than', 'куда', 'ее', 'both', 'когда', 'hasn', 'some', 'их', 'про', 'потому', 'где', 'этой', "needn't", 'ли', 'тот', 'и', 'два', "that'll", "i'm", 'i', 'этого', 'are', 'that', "they'll", 'да', 'был', 'лучше', 'ведь', 'itself', 'наконец', "we're", 'вас', 'd', 'может', 'так', 'ней', 'разве', 'of', 'until', 'под', 'its', 'ему', 'during', 'если', 'уж', 'какая', "hasn't", 'ours', 'впрочем', 'во', 'еще', 'after', 'после', 'being', 'was', 'можно', 'более', 'для', 'нее', 'only', 'между', "won't", 'll', 'any', 'over', 'other', 'иногда', 'потом', 'себя', 'whom', 'you', 'ain', 'in', 'who', 'by', 'один', 'such', 'том', 'there', 'какой', 'no', 'now', 'out', 'should', 'below', 'только', 'doesn', 'were', 'will', 'того', 'here', 'down', 'была', 'she', 'же', 'чем', 'just', 'it', 'от', 'здесь', 'what', 'больше', 'чуть', "she's", 'y', 'или', "aren't", 'our', "mustn't", 'they', "wasn't", 'кто', 'don', "it'll", 'чтобы', 'be', 'три', 'без', 'me', 'до', 'мы', 'her', 'isn', 'уже', 'few', "hadn't", 'their', "shouldn't", 'or', "isn't", 'хорошо', 'зачем', 'needn', 'надо', 'further', 'has', 'aren', 'вдруг', 'моя', 'тут', "you'd", 'было', 'too', "shan't", 'can', 'хоть', 'быть', 'a', 'to', 'been', 'again', 'with', 'никогда', 'а', 'не', 'тогда', 'нас', "i've", 'themselves', 'даже', "we've", 'more', 'теперь', 'ну', 'ей', "he'll", 'меня', 'него', 'through', 'yourselves', "doesn't", 'такой', 'while', 'before', "they've", 'o', 'above', 'm', 'into', "they're", 'herself', 'myself', 'перед', 'тем', 'в', 'as', 'my', 'them', 'вам', 'these', 'those', 'own', 'ж', 'совсем', "i'll", 'через', "you've", 'ничего', "didn't", 'each', "he's"}

# %% [markdown]
# 7. Применим нашу функцию для фильтрации данных
#
# *В переменной `all_stopwords` должен быть результат объединения множеств из пункта 6*

# %%
# Фильтруем стоп-слова
meaningful_words = filter_stopwords(words, all_stopwords)

# %% [markdown]
# Выведите на экран список `meaningful_words`, а также длину этого списка

# %%
print(meaningful_words)
print(len(meaningful_words))
# Out:
# ['sample', 'text', 'processing', 'contains', 'stopwords', 'important', 'words', 'текст', 'содержит', 'английские', 'русские', 'слова', 'включая', 'стопслова']
# 14

# %% [markdown]
# 8. Создаем множество уникальных значимых слов
#
# *Конвертируем список `meaningful_words` к виду множества*

# %%
unique_meaningful_words = set(meaningful_words)

# %% [markdown]
# Выведите на экран результат, а также длину полчившегося множества

# %%
print(unique_meaningful_words)
print(len(unique_meaningful_words))
# Out:
# {'sample', 'contains', 'текст', 'слова', 'включая', 'русские', 'processing', 'important', 'содержит', 'английские', 'stopwords', 'стопслова', 'words', 'text'}
# 14

# %% [markdown]
# 9. Создайте отчет
#
# - выведите исходное количество стоп-слов на английском
# - исходное количество слов на русском
# - общее количество стоп-слов

# %%
print("Количество английских стоп-слов:", len(stopwords_english))
print("Количество русских стоп-слов:", len(stopwords_russian))
print("Общее количество стоп-слов (объединённое множество):", len(all_stopwords))
# Out:
# Количество английских стоп-слов: 198
# Количество русских стоп-слов: 151
# Общее количество стоп-слов (объединённое множество): 349

# %% [markdown]
# 10. Проведите анализ результатов: какие стоп-слова были удалены из исходного текста?
#
# - создайте список для сохранения отфильтрованных слов
# - для каждого слова исходного текста (`text`)
# - если данное слово было в списке стоп-слов
# - добавляем его в созданный список
#
# *Выведите на экран отфильтрованные слова (т.е. удаленные)*

# %%
removed_stopwords = []
for word in words:
    if word in all_stopwords:
        removed_stopwords.append(word)
print("Удалённые стоп-слова:", removed_stopwords)
# Out:
# Удалённые стоп-слова: ['this', 'is', 'a', 'for', 'it', 'some', 'and', 'этот', 'как', 'так', 'и']
